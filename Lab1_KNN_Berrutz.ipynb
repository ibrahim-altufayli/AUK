# %% [markdown]
# # Lab 1 - K-Nearest Neighbours
#
# This lab is about the implementation and analysis of the KNN algorithm for classification problems

# %%
### If you use colab uncomment these line and upload Material.zip

#from google.colab import files

#files.upload()
#!unzip Material.zip

# %%
# Packages used
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
from scipy.interpolate import griddata
import os
import pickle
np.random.seed(100)

# %% [markdown]
# ### Data generation for binary classification
#
# We start generating a training set for binary classification problems. Consider the following function, that generates random 2D points on the plane and assigns them a binary label according to their position w.r.t. (WITH REFERENCE TO) a linear separator.
#
# The function `linearBinaryClass`, given a sample size `n`, lower and upper bounds `low_D, high_D` for the domain of the samples and the linear function parameters `m, q`, generates a binary classification dataset i.e. it returns `X` and `Y`.
#
# The signature of the function is the following:
#
# `X, Y = linearBinaryClass(n, low_D, high_D, m, q)`
#
# where
# - **n** is the number of samples to be generated
# - **low_D** and **high_D** are, respectively, the lower and upper bounds for the domain of the samples i.e.
# $$
# X_{i,j} \sim \mathcal{U}(\text{low-D}, \text{high-D})
# $$
# - **m, q** are the linear function parameters
# - **X**, **Y**: 2-dimensional samples (X) associated with 1-dimensional binary labels (Y)

# %%
def linearBinaryClass(n, low_D, high_D, m, q):
    X = (np.random.rand(n, 2) * (high_D - low_D)) + low_D
    Y = np.sign((X[:,1] - (m * X[:,0]) + q))
    Y[Y==0] = 1
    return X,Y

# %% [markdown]
# ### Computing the distance between input points
#
# In order to build the KNN estimator we need to resort to a distance function.
#
# Consider a function that computes the euclidean distance between two points...

# %%
def euclidDistance(P1,P2):
    return np.linalg.norm(P1-P2,2)

# %% [markdown]
# ... and then a function that computes all the distance between two set of points stored in two matrices.

# %%
def allDistances(X1, X2):
    D = np.zeros((X1.shape[0], X2.shape[0]))
    for idx1 in range(len(X1)):
        for idx2 in range(len(X2)):
            D[idx1,idx2] = euclidDistance(X1[idx1,:],X2[idx2,:])
    return D

# %% [markdown]
# The usage is the following:
#
# **D = allDistances(X1,X2)**
#
# where
# - **X1** is a matrix of size $n_1 \times D$, where each row is a D-dimensional point
# - **X2** is a matrix of size $n_2 \times D$, where each row is a D-dimensional point
# - **D** is a matrix of size $n_1 \times n_2$, where each element `D[i,j]` is the distance between points (`X1[i, :]`, `X2[j, :]`)

# %% [markdown]
# ### Adding noise to the samples
#
# To make the task harder, we may want to perturb the labels with some noise.
#
# In our case, we have binary labels and a common way of adding noise is to flip the value of a small percentage of the labels. For example, if a label was $+1$ it will become $-1$.
#
# The `flipLabels` function takes two arguments:
#  - `Y`, the numpy array of original labels
#  - `P`, an integer between 1 and 100 specifying the percentage of labels which will be flipped
# and returns an array of the same shape as `Y`, which contains the noisy labels.

# %%
def flipLabels(Y, P):
    if P < 1 or P > 100:
        raise Exception('P should be between 1 and 100')
        
    indices_to_flip = np.random.choice(range(len(Y)), int(len(Y) * (P / 100)), replace=False)
    Y_noisy = Y.copy()
    Y_noisy[indices_to_flip] *= -1
    
    return Y_noisy

# %% [markdown]
# ------------------------------------------

# %% [markdown]
# ### Assignment 1: The KNN classifier
#
# We are now ready to use the KNN algorithm to estimate the classification function.
#
# Implement the `kNNClassify` function which train a KNN classifier on given training set and returns predictions on a given test set.
#
# The signature of the function is the following:
#
# `Ypred = kNNClassify(Xtr, Ytr, k, Xte)`
#
# where
# - **Xtr** is a matrix of size [ntr, D], where each row is a D-dimensional point (INPUT IN THE **TRAINING SET**)
# - **Ytr** is an array of size [ntr], where each element is a binary label (OUTPUT IN THE **TRAINING SET**)
# - **k** is the number of neighbours to be considered
# - **Xte** is a matrix of size [nte, D], where each row is a D-dimensional point (INPUT IN THE **TEST SET**)
# - **Ypred** is an array of size [nte], where each element is a binary label (ESTIMATED OUTPUT FOR THE **TEST SET**)
#
# where [ntr] and [nte] are respectively the number of points in the training set and the number of points in the test set

# %%
from re import X


def kNNClassify(Xtr, Ytr, k, Xte):

    n_train = Xtr.shape[0] # number of the training inputs
    n_test = Xte.shape[0] # number of the test inputs

    if any(np.abs(Ytr) != 1):
        raise Exception("The values of Ytr should be +1 or -1.")

    if k > n_train:
        print("k is greater than the number of points, setting k=n_train")
        k = n_train

    Ypred = np.zeros(n_test)

    # Compute all the distances from TEST input and TRAINING input
    dist = allDistances(Xte,Xtr)
    #print("Matrix of distances: ",dist.shape)

    # For each test point, the predicted class will be 
    # the sign of the average label of the k nearest points
    for idx in range(n_test):
        # Hint 1: take all the distances for the current test point
        distance_matrix= dist[idx]
        # Hint 2: Sort the indices of the distance
        sorted_index = np.argsort(distance_matrix)
        # Hint 3: Get the indices of the k lowest of distances
        k_lowest = sorted_index[:k]
        #print(k_lowest)
        # Hint 4: Compute the mean of the output values of the corresponding training points and 
        # taking the sign of it.
        Ypred[idx] = np.sign(np.mean(Ytr[k_lowest]))

    return Ypred

# %% [markdown]
# ### Visualizing the separating function
#
# The visualization of the separating function on the training set, i.e. the function estimated by classification algorithm for discriminating between classes, is of benefit for appreciating the behavior of
# the binary classifier. To visualize the separating function use the following:
#
# **_separatingFkNN(Xtr, Ytr, k)_**
#
# where
# - **Xtr** is a matrix of size [ntr, D], where each row is a D-dimensional point (INPUT IN THE **TRAINING SET**)
# - **Ytr** is an array of size [ntr], where each element is a binary label (OUTPUT IN THE **TRAINING SET**)
# - **k** is the number of neighbours to be considered

# %%
def separatingFkNN(Xtr, Ytr, k, Xte):
    Ypred = kNNClassify(Xtr=Xtr, Ytr=Ytr, k=k, Xte=Xte)

    x = Xtr[:, 0] # take all the x axis
    y = Xtr[:, 1] # take all the y axis
    xi = np.linspace(x.min(), x.max(), 200) # create an array of 200 points between the bound based on value on x 
    yi = np.linspace(y.min(), y.max(), 200)
    zi = griddata((x, y), Ypred, (xi[None, :], yi[:, None]), method='linear') #Array of interpolated values.

    plt.subplots()
    CS = plt.contour(xi, yi, zi, 15, linewidths=2, colors='k', levels=[0])
    # plot data points.
    plt.scatter(x, y, c=Ytr, marker='o', s=50, zorder=10, alpha=0.8)
    plt.xlim(x.min(), x.max())
    plt.ylim(x.min(), x.max())
    msg = 'Separating function, k='+str(k);
    plt.title(msg)

# %% [markdown]
# ### Evaluating the goodness of a classifier
#
# To evaluate how good is the classification function estimated by the KNN, we compare the predicted binary labels and expected (true) ones, with the following function:
#
# `err = calcError(Ypred, Ytrue)`
#
# where
# - **Ypred** is an array of size $n$, where each element is a binary label predicted by the classifier
# - **Ytrue** is an array of size $n$, where each element is the true binary label
# - **err** is the fraction of wrongly classified elements wrt the total number

# %%
def calcError(Ypred, Ytrue):
    return (np.count_nonzero(Ypred != Ytrue)) / len(Ytrue)

# %%
from sklearn.neighbors import KNeighborsClassifier

#TODO: Evaluate the NN classifier on the Training set on scikit-learn
def Evaluate_scikit(Xtr,Ytr,Xte,Yte,k):
    neigh = KNeighborsClassifier(n_neighbors=k)
    neigh.fit(Xtr,Ytr)
    yPred_scikit_tr = neigh.predict(Xtr)
    err = calcError(yPred_scikit_tr,Ytr)
    print("With K=%d the error in scikit-learn on the TRAINING SET (with CALCERROR) is " % (k), err)
    
    yPred_scikit_te = neigh.predict(Xte)
    err = calcError(yPred_scikit_te,Yte)
    print("With K=%d the error in scikit-learn on the TEST SET (with CALCERROR) is " % (k), err)

    err = neigh.score(Xtr,Ytr)
    print("With K=%d the RIGHT PART in scikit-learn on the TRAINING SET (with SCORE) is " % (k), err)
    
    err = neigh.score(Xte,Yte)
    print("With K=%d the RIGHT PART in scikit-learn on the TEST SET (with SCORE) is " % (k), err)

# %% [markdown]
# -----------------------------------------------

# %% [markdown]
# ### Assignment 2: Noise-free case
#
# In this assignment, we start to play with the NN classifier. In specific:
#
# - 1.Generate a training set WITHOUT NOISE
# - 2.Visualize the separating curve for the **NN** classifier
# - 3.Generate a test set with the same amount of noise as the training set.
# - 4.Compute the error on the TRAINING and then on the TEST SET

# %%
### Generate training and test sets, build and evaluate the KNN classifier

n = 200
D = 2

m = 0.9
q = 0.0

low_D = -10
high_D = 10

k = 1

#TODO: Generate a training set WITHOUT NOISE
Xtr, Ytr = linearBinaryClass(n,low_D,high_D,m,q)

#TODO: Visualize the separating curve for the NN classifier on the TRAINING SET
separatingFkNN(Xtr,Ytr,k,Xtr)

#TODO: Generate a test set WITHOUT NOISE
Xte, Yte = linearBinaryClass(n,low_D,high_D,m,q)

#TODO: Evaluate the NN classifier on the TEST SET
Ypred = kNNClassify(Xtr,Ytr,k,Xte)

#TODO: Compute the error on the TEST SET
err = calcError(Ypred,Yte)

print("With K=%d the error on the test set is " % (k), err)

# How the classifier perform on the TRAINING SET instead?
Ypredtr = kNNClassify(Xtr,Ytr,k,Xtr)

errtr = calcError(Ypredtr,Ytr)
print("With K=%d the error on the training set is " % (k), errtr)


#TODO: Evaluate the NN classifier on the Training set on scikit-learn
Evaluate_scikit(Xtr,Ytr,Xte,Yte,k)

# Paying attention to K=1 neighbours the rusult is this:
# On TRAINING SET the error is 0 , because if the points are the same and watching only 1 neighbour is obviosly catching the same value
# On Test set is around 0.035 , 0,015 .. depends on the random created point
# Out:
# With K=1 the error on the test set is  0.03
# With K=1 the error on the training set is  0.0
# With K=1 the error in scikit-learn on the TRAINING SET (with CALCERROR) is  0.0
# With K=1 the error in scikit-learn on the TEST SET (with CALCERROR) is  0.03
# With K=1 the RIGHT PART in scikit-learn on the TRAINING SET (with SCORE) is  1.0
# With K=1 the RIGHT PART in scikit-learn on the TEST SET (with SCORE) is  0.97

# %% [markdown]
# ---------------------------------------------------

# %% [markdown]
# ### Assignment 3: adding noise
#
# Keeping the parameters of the function and the number of points as in the previous assignment:
#
# - 1.Generate a training set WITH NOISE (for instance with 10% of flipped labels)
# - 2.Visualize the separating curve for the **NN** classifier
# - 3.Generate a test set with the same amount of noise as the training set.
# - 4.Evaluate the NN classifier on the TRAINING and on the TEST SET
# - 5.Compute the obtained error on the TRAINING and on the TEST SET
#
# - Repeat the steps from 1 to 5 with the **KNN** algorithm, setting for instance K=5
#
# OBSERVE WHAT CHANGES...

# %%
# ... your code goes here... #
def Assignment_3(num,k,P):
    # 1.
    Xtr,Ytr = linearBinaryClass(num,low_D,high_D,m,q)
    Ytr = flipLabels(Ytr,P)

    # 2.
    separatingFkNN(Xtr,Ytr,k,Xtr) # Xtr is the same but Ytr is perturbated , so the predicted value of Xtr change
    msg = 'Separating function, k='+str(k)+" n="+str(num)+" P="+str(P);
    plt.title(msg)

    # 3.
    Xte,Yte = linearBinaryClass(num,low_D,high_D,m,q)
    Yte = flipLabels(Yte,P)

    #3.5 Search in scikit-learn
    
    # 4. 
    YPre_tr = kNNClassify(Xtr,Ytr,k,Xtr)
    YPre_te = kNNClassify(Xtr,Ytr,k,Xte)

    #5.
    err = calcError(YPre_tr,Ytr)
    print("With K=%d the error on the Training set is " % (k), err)

    err = calcError(YPre_te,Yte)
    print("With K=%d the error on the Test set is " % (k), err)
    
    Evaluate_scikit(Xtr,Ytr,Xte,Yte,k)

# changing values of k
P=10
k=1
Assignment_3(n,k,P)

k=5
Assignment_3(n,k,P)

k=10
Assignment_3(n,k,P)
# Out:
# With K=1 the error on the Training set is  0.0
# With K=1 the error on the Test set is  0.19
# With K=1 the error in scikit-learn on the TRAINING SET (with CALCERROR) is  0.0
# With K=1 the error in scikit-learn on the TEST SET (with CALCERROR) is  0.19
# With K=1 the RIGHT PART in scikit-learn on the TRAINING SET (with SCORE) is  1.0
# With K=1 the RIGHT PART in scikit-learn on the TEST SET (with SCORE) is  0.81
# With K=5 the error on the Training set is  0.115
# With K=5 the error on the Test set is  0.145
# With K=5 the error in scikit-learn on the TRAINING SET (with CALCERROR) is  0.115
# With K=5 the error in scikit-learn on the TEST SET (with CALCERROR) is  0.145
# With K=5 the RIGHT PART in scikit-learn on the TRAINING SET (with SCORE) is  0.885
# With K=5 the RIGHT PART in scikit-learn on the TEST SET (with SCORE) is  0.855
# With K=10 the error on the Training set is  0.135
# With K=10 the error on the Test set is  0.11
# With K=10 the error in scikit-learn on the TRAINING SET (with CALCERROR) is  0.12
# With K=10 the error in scikit-learn on the TEST SET (with CALCERROR) is  0.11
# With K=10 the RIGHT PART in scikit-learn on the TRAINING SET (with SCORE) is  0.88
# With K=10 the RIGHT PART in scikit-learn on the TEST SET (with SCORE) is  0.89

# %% [markdown]
# Describe here what changes:
# - case where k = 1 on the perturbated TRAINING SET (of 10%) , the error on the Training set is  0.0 and the error on the Test set is  0.52 . The same as the result without noise
# - while increasing k=5 for example on the perturbated TRAINING SET the error on the Training set is  0.105 that means that is increasing watching a larger portion of neighbours and
# at the same time  the error on the Test set is  0.485 , so is descreasing compared to the previous result on k=1
# - In conclusion With K=50 the error on the Training set is  0.125 and the error on the Test set is  0.515 this means that the error on the TRAINING set is increasing and
# descresing for the training set
# - All my assumptions depends on the result comnputed with random data generated randomically
# - Maybe the right best k to have a good approximation to the TEST set is between 1 and 50
# - And watching the plot more k is small more the function fall in love with data (more fitting on data) ,  increasing the k the function generalize more

# %% [markdown]
# ------------------------------------------------------------------

# %% [markdown]
# ### Assignment 4
#
# Analyse the performance of the **KNN** with plots, considering in particular the following:
#
#
#
# - **SCENARIO 1**: Fix the number n of points to 200, fix the amount of noise to 10%, and plot the performance of the KNN classifier on TRAINING and TEST SETS as you increase the value of K
#
# - **SCENARIO 2**: Fix the number n of points to 200, fix the value of K to a reasonable number of neighbours, and plot the performance of the KNN classifier on TRAINING and TEST SETS as you increase the amount of noise
#
# - **SCENARIO 3**: Fix noise and K to two reasonable values, fix the number of TEST samples to 300, and plot the performance of the KNN classifier on TRAINING and TEST SETS as you increase the number of TRAINING samples (e.g. from 30 to 300 with steps 30)
#
# For each scenario, describe what happen

# %%
# Function where the difference Betweeen Assignment_3 is that the same where calculte KNN are passed 
def Assignment_4( Xtr,Ytr,Xte,Yte,num,k,P):
    # 3.1. Already created

    # 3.2.
    separatingFkNN(Xtr,Ytr,k,Xtr) # Xtr is the same but Ytr is perturbated , so the predicted value of Xtr change
    msg = 'Separating function, k='+str(k)+" n="+str(num)+" P="+str(P);
    plt.title(msg)

    # 3.3 Already created

    # 3.4
    YPre_tr = kNNClassify(Xtr,Ytr,k,Xtr)
    YPre_te = kNNClassify(Xtr,Ytr,k,Xte)

    # 3.5
    err = calcError(YPre_tr,Ytr)
    print("With K=%d , N=%d , P=%d the error on the Training set is " % (k,num,P) , err)

    err = calcError(YPre_te,Yte)
    print("With K=%d , N=%d , P=%d the error on the Test set is " % (k,num,P) , err)
    
    #Evaluate_scikit(Xtr,Ytr,Xte,Yte,k)

# %%
# ... your code for SCENARIO 1 goes here...
#SCENARIO 1 : Fix the number n of points to 200, fix the amount of noise to 10%, and plot the performance of the KNN classifier on TRAINING and TEST SETS as you increase the value of K
num = 200
P=10

Xtr,Ytr = linearBinaryClass(num,low_D,high_D,m,q)
Yte = flipLabels(Ytr,P)
Xte,Yte = linearBinaryClass(num,low_D,high_D,m,q)
Yte = flipLabels(Yte,P)

# changing values of k
k=1
Assignment_4(Xtr,Ytr,Xte,Yte,n,k,P)
k=5
Assignment_4(Xtr,Ytr,Xte,Yte,n,k,P)
k=10
Assignment_4(Xtr,Ytr,Xte,Yte,n,k,P)

# The function , on the parameter (n=200,P=10) chosen in SCENARIO 1 , generalize more when k increase , and fall in love with data when k is low obviously
# Meanwhile the ERROR on the TRAING SET , on the parameter (n=200,P=10) chosen in SCENARIO 1 , increase increasing K 
# And the ERROR on the TEST SET , on the parameter (n=200,P=10) chosen in SCENARIO 1 , descrease increasing K , how we see on the Assignement 3
# Out:
# With K=1 , N=200 , P=10 the error on the Training set is  0.0
# With K=1 , N=200 , P=10 the error on the Test set is  0.11
# With K=5 , N=200 , P=10 the error on the Training set is  0.015
# With K=5 , N=200 , P=10 the error on the Test set is  0.095
# With K=10 , N=200 , P=10 the error on the Training set is  0.03
# With K=10 , N=200 , P=10 the error on the Test set is  0.115

# %%
# ... your code for SCENARIO 2 goes here...
# SCENARIO 2: Fix the number n of points to 200, fix the value of K to a reasonable number of neighbours, and plot the performance of the KNN 
# classifier on TRAINING and TEST SETS as you increase the amount of noise
n = 200
k=3

Xtr_base,Ytr_base = linearBinaryClass(num,low_D,high_D,m,q)
Xte_base,Yte_base = linearBinaryClass(num,low_D,high_D,m,q)

# changing values of P
P=10
Ytr = flipLabels(Ytr_base,P)
Yte = flipLabels(Yte_base,P)
Assignment_4(Xtr,Ytr,Xte,Yte,n,k,P)
P=50
Ytr = flipLabels(Ytr_base,P)
Yte = flipLabels(Yte_base,P)
Assignment_4(Xtr,Ytr,Xte,Yte,n,k,P)
P=75
Ytr = flipLabels(Ytr_base,P)
Yte = flipLabels(Yte_base,P)
Assignment_4(Xtr,Ytr,Xte,Yte,n,k,P)
P=90
Ytr = flipLabels(Ytr_base,P)
Yte = flipLabels(Yte_base,P)
Assignment_4(Xtr,Ytr,Xte,Yte,n,k,P)

# The function , on the parameter (n=200,K=3) chosen in SCENARIO 2 , observed also in the training set presents in the plot not an incredible accuracy that became worst adding NOISE
# Meanwhile the ERROR on the TRAING SET , on the parameter (n=200,K=3) chosen in SCENARIO 2 , tells that on the same data changing the amount of noise the error ( in most case ) increase 
# And the ERROR on the TEST SET , on the parameter (n=200,K=3) chosen in SCENARIO 2 , observing the data not change too much , being stable up to 0.5 in error percentage ( in most case )
# Out:
# With K=3 , N=200 , P=10 the error on the Training set is  0.21
# With K=3 , N=200 , P=10 the error on the Test set is  0.55
# With K=3 , N=200 , P=50 the error on the Training set is  0.27
# With K=3 , N=200 , P=50 the error on the Test set is  0.53
# With K=3 , N=200 , P=75 the error on the Training set is  0.215
# With K=3 , N=200 , P=75 the error on the Test set is  0.51
# With K=3 , N=200 , P=90 the error on the Training set is  0.265
# With K=3 , N=200 , P=90 the error on the Test set is  0.5

# %%
# ... your code for SCENARIO 3 goes here...
# Fix noise and K to two reasonable values, fix the number of TEST samples to 300, and plot the 
# performance of the KNN classifier on TRAINING and TEST SETS as you increase the 
# number of TRAINING samples (e.g. from 30 to 300 with steps 30)
P=10
k=3
n_te = 300
n_tr = 30 

Xte,Yte = linearBinaryClass(n_te,low_D,high_D,m,q)
Yte = flipLabels(Yte,P)

# changing values of the increase the number of training samples by step 30
for i in range(n_tr,330,30):

    Xtr,Ytr = linearBinaryClass(i,low_D,high_D,m,q)
    Ytr = flipLabels(Ytr,P)

    # 2.
    separatingFkNN(Xtr,Ytr,k,Xtr)
    msg = 'Separating function, k='+str(k)+" n="+str(i)+" P="+str(P);
    plt.title(msg)

    # 3. Already created

    # 4. 
    YPre_tr = kNNClassify(Xtr,Ytr,k,Xtr)
    YPre_te = kNNClassify(Xtr,Ytr,k,Xte)

    #5.
    err = calcError(YPre_tr,Ytr)
    print("With K=%d , N=%d , P=%d the error on the Training set is " % (k,i,P) , err)

    err = calcError(YPre_te,Yte)
    print("With K=%d , N=%d , P=%d the error on the Test set is " % (k,i,P) , err)
    
    #Evaluate_scikit(Xtr,Ytr,Xte,Yte,k)

# The ERROR on the TRAINING SET , on the parameter (n=200,K=3) chosen in SCENARIO 2 , tells that changing the amount of data to compute in the KNN the error ( in most case ) remain stable (ex. from 0.12 to 0.073 )
# And the ERROR on the TEST SET , on the parameter (n=200,K=3) chosen in SCENARIO 2 , observing the data the error remain being stable but variates more than the TRAINING SET in error percentage ( in most case )
# Pay attention that adding data the function fall in love with data generalize more
# Out:
# With K=3 , N=30 , P=10 the error on the Training set is  0.1
# With K=3 , N=30 , P=10 the error on the Test set is  0.20333333333333334
# With K=3 , N=60 , P=10 the error on the Training set is  0.13333333333333333
# With K=3 , N=60 , P=10 the error on the Test set is  0.16
# With K=3 , N=90 , P=10 the error on the Training set is  0.07777777777777778
# With K=3 , N=90 , P=10 the error on the Test set is  0.16666666666666666
# With K=3 , N=120 , P=10 the error on the Training set is  0.1
# With K=3 , N=120 , P=10 the error on the Test set is  0.17666666666666667
# With K=3 , N=150 , P=10 the error on the Training set is  0.1
# With K=3 , N=150 , P=10 the error on the Test set is  0.17333333333333334
# With K=3 , N=180 , P=10 the error on the Training set is  0.09444444444444444
# With K=3 , N=180 , P=10 the error on the Test set is  0.18333333333333332
# With K=3 , N=210 , P=10 the error on the Training set is  0.1
# With K=3 , N=210 , P=10 the error on the Test set is  0.18
# With K=3 , N=240 , P=10 the error on the Training set is  0.09583333333333334
# With K=3 , N=240 , P=10 the error on the Test set is  0.13666666666666666
# With K=3 , N=270 , P=10 the error on the Training set is  0.1111111111111111
# With K=3 , N=270 , P=10 the error on the Test set is  0.15666666666666668
# With K=3 , N=300 , P=10 the error on the Training set is  0.12666666666666668
# With K=3 , N=300 , P=10 the error on the Test set is  0.17333333333333334

# %% [markdown]
# Insert here your observations:
# - **SCENARIO 1**:
# - The function , on the parameter (n=200,P=10) chosen in SCENARIO 1 , generalize more when k increase , and fall in love with data when k is low obviously
#  - Meanwhile the ERROR on the TRAING SET , on the parameter (n=200,P=10) chosen in SCENARIO 1 , increase increasing K
#  - And the ERROR on the TEST SET , on the parameter (n=200,P=10) chosen in SCENARIO 1 , descrease increasing K , how we see on the Assignement 3
# - **SCENARIO 2**:
#  - The function , on the parameter (n=200,K=3) chosen in SCENARIO 2 , observed also in the training set presents in the plot not an incredible accuracy that became worst adding NOISE
#  - Meanwhile the ERROR on the TRAING SET , on the parameter (n=200,K=3) chosen in SCENARIO 2 , tells that on the same data changing the amount of noise the error ( in most case ) increase
#  - And the ERROR on the TEST SET , on the parameter (n=200,K=3) chosen in SCENARIO 2 , observing the data not change too much , being stable up to 0.5 in error percentage ( in most case )
# - **SCENARIO 3**:
#  - The ERROR on the TRAINING SET , on the parameter (n=200,K=3) chosen in SCENARIO 2 , tells that changing the amount of data to compute in the KNN the error ( in most case ) remain stable (ex. from 0.12 to 0.073 )
#  - And the ERROR on the TEST SET , on the parameter (n=200,K=3) chosen in SCENARIO 2 , observing the data the error remain being stable but variates more than the TRAINING SET in error percentage ( in most case )
#  - Pay attention that adding data the function fall in love with data generalize more

# %% [markdown]
# ------------------------------------------------------------

# %% [markdown]
# ## Cross-validation
# In this part of the Lab, we focus on Cross-validation for model selection.

# %% [markdown]
# ### Preliminaries: Data-loading
#
# There are 4 datasets included with this lab, with the following properties:
#
#   - (Training1, Test1): n=70, no noise, suggested K values are in the range 1 ... 13
#   - (Training2, Test2): n=40, no noise, suggested K values are in the range 1 ... 23
#   - (Training3, Test3): n=200, 20% flipped labels, suggested K values are in the range 1 ... 31
#   - (Training4, Test4): n=200, 5% flipped labels, suggested K values are in the range 1 ... 19
#
# Note that each dataset includes both a training and a test set. You **cannot use the test set to choose k**: you should assume you don't have access to the test set when doing model selection!

# %% [markdown]
# To load a dataset use function
# `Xtr, Ytr, Xte, Yte = load_dataset(path_tr, path_te)`
#
# Where:
# - **_path\_tr_**: is the path to the file which contains the training set
# - **_path\_te_**: is the path to the file which contains the test set
#
# and it returns:
# - **_Xtr_**: Inputs of training set
# - **_Ytr_**: Outputs of training set
# - **_Xte_**: Inputs of test set
# - **_Yte_**: Outputs of test set

# %%
def load_dataset(path_tr, path_te):
    with open(path_tr,"rb") as f:
        [Xtr, Ytr] = pickle.load(f)
    with open(path_te,"rb") as f:
        [Xte, Yte] = pickle.load(f)
    return Xtr, Ytr, Xte, Yte

# %%
training_set_path = "./Material/Classification/Training4.dat"
test_set_path = "./Material/Classification/Test4.dat"
Xtr, Ytr, Xte, Yte = load_dataset(training_set_path, test_set_path)
separatingFkNN(Xtr, Ytr, 1, Xtr)

# function fit a lot in Xtr because k=1

# %% [markdown]
# ----------------------------------------------------------------

# %% [markdown]
# ## Assignment 5: using the training set to choose k
#
# Having noted that we cannot directly use the test set to find the best k, we can try to select it with the training set.
# Follow these steps, and fill in the blanks in the following cells. **Comment on your findings in the notebook**.
#
#  1. Choose a list of values for k you want to try. Check the list of suggested values for any given dataset.
#  2. For each value of k do:
#      1. Train a k-NN classifier with the current value of k
#      2. Evaluate the error of the trained model, **on the training set**
#  3. The _best_ k is the one with the lowest training error!
#  4. Train a k-NN model with the chosen k, and evaluate the error **on the test set**. Is the test error similar to the training error? Does the chosen k seem like a good one?

# %%
#from sklearn.metrics import f1_score

def Evaluate_best_k(k_list,Xtr,Ytr,Xte,Yte):
    fls= []
    
    for i in k_list:
        knn = KNeighborsClassifier(n_neighbors=i)
        knn.fit(Xtr,Ytr)
        pred_i = knn.predict(Xte)
        fls.append(calcError(pred_i,Yte))
        
    return fls

# %%
# Use dataset 4 for this task.
Xtr, Ytr, Xte, Yte = load_dataset(training_set_path, test_set_path)
#1. Choose a list of values of k based list of suggested ( in this example of dataset 4 range (1...19) )
k_list = list(range(1,20))
#print(k_list_4)

# Insert your code here
k_tr_errors = []
for current_k in k_list:
    # 2. TODO: train a k-NN model, calculate the error on the training set.
    Ypre_tr =  kNNClassify(Xtr,Ytr,current_k,Xtr)
    current_tr_err = calcError(Ypre_tr,Ytr)
    k_tr_errors.append(current_tr_err)

# 3. The best k k is the one with the lowest training error
# TODO: pick the best value of k using k_list and k_tr_errors.
best_k = k_list[np.argmin(k_tr_errors)]

print(f"The best k chosen with the training-set is: {best_k}\n"
      f"with training error {np.min(k_tr_errors)*100:.2f}%")
# Out:
# The best k chosen with the training-set is: 1
# with training error 0.00%

# %%
################# Evaluate best k with Scikit #################
#k_tr_errors_scikit = Evaluate_best_k(k_list_4,Xtr,Ytr,Xtr,Ytr)
# TODO: pick the best value of k using k_list and k_tr_errors.
#best_k_scikit = k_list_4[np.argmin(k_tr_errors_scikit)]
#print(f"The best k chosen with the training-set is: {best_k_scikit}\n"
#      f"with training error {np.min(k_tr_errors_scikit)*100:.2f}%")
##################################

# %%
# 4. Evaluate the model with the best k on the test set now
Ypre_best_k =  kNNClassify(Xtr,Ytr,best_k,Xte)
te_err = calcError(Ypre_best_k,Yte)
    
print(f"The test error with the best k ({best_k}) is: {te_err*100:.2f}%")
# Out:
# The test error with the best k (1) is: 12.00%

# %%
# Plot how the training error changes with k
fig, ax = plt.subplots()
ax.plot(k_list, k_tr_errors)
ax.set_xlabel("k")
ax.set_ylabel("training error")
ax.set_title("Choosing k from the training set.")

# Plot explaing that increasing K on evaluating the model you add error 


##### Plot how the training error changes with k on Scikit #####
#fig, ax = plt.subplots()
#ax.plot(k_list_4, k_tr_errors_scikit)
#ax.set_xlabel("k")
#ax.set_ylabel("training error")
#ax.set_title("Choosing k from the training set.")
# Plot explaing that increasing K on evaluating the model you add error
# Out:
# Text(0.5, 1.0, 'Choosing k from the training set.')

# %% [markdown]
# #### Observations: ...
# - Obviously selecting K=1 and not having access to the Test Set to create the model , the best_k with lowest error will always be K=1
# - So the training error does not provide good estimates of the test error
# - Using the best_k based on the TRAINING SET , the result by evaluating the model on the TEST SET return an bigger error than the other k , so selecting another k different from best_k its possible to achive a smaller error
# - In conclusion it not looks like a good one
# - Just to prove it , you can prove to evaluate the model with k=19 for example and find an error on TEST SET that is lower on the best_k

# %% [markdown]
# ----------------------------------------------------------------------

# %% [markdown]
# ## Assignment 6: K-Fold cross validation
#
# The training error does not provide good estimates of the test error. So using the training error for model selection means you will select a k which is not good for the test set.
#
# A simple way, which is much better than the training error, to estimate the test error is to use a **k-fold cross validation**. In K-Fold cross validation, the data are split into K parts of approximately equal size, and K different models are trained each time leaving out one of the parts of data. Then the estimate for the test error is the mean of the error of the K different models.
#
# In this task you will implement K-Fold CV, and run the same analysis as in the previous cell.

# %%
from sklearn.model_selection import cross_validate , KFold

def KFoldCvKnn_scikit(Xtr,Ytr,num_folds,k_list_4):
    kf = KFold(num_folds)
    res = cross_validate(kf,Xtr,Ytr,cv=5)
    return res

###### K-FOLD Scikit #####
#ris = KFoldCvKnn_scikit(Xtr,Ytr,num_folds,k_list_4)
#print(ris)
###########

# %%
def KFoldCVkNN(Xtr, Ytr, num_folds, k_list):
    """Run K-Fold CV for the kNN model
    
    Parameters:
    -----------
     - Xtr : np.array
         the full training set data
     - Ytr : np.array
         the full training set labels
     - num_folds : int
         the number of folds
     - k_list : List[int]
         the values of k (for k-NN) to try.
         
    Returns:
    --------
     - best_k : int
         The value of k (in k_list) which obtains the best average validation error
     - best_k_idx : int
         The index of the best_k element in k_list
     - tr_err_mean : np.array
         A 1D array of the same length as k_list, with the average training error for each tested k.
     - tr_err_std : np.array
         A 1D array of the same length as k_list, with the standard deviation 
         of the training error for each tested k.
     - val_err_mean : np.array
         A 1D array of the same length as k_list, with the average validation error for each tested k.
     - val_err_std : np.array
         A 1D array of the same length as k_list, with the standard deviation
         of the validation error for each tested k.
    """
    rnd_state = np.random.RandomState()
    # Ensures that k_list is a numpy array
    k_list = np.array(k_list)
    num_k = len(k_list)

    n_tot = Xtr.shape[0]
    n_val = n_tot // num_folds

    # We want to compute 1 error for each `k` and each fold
    tr_errors = np.zeros((num_k, num_folds))
    val_errors = np.zeros((num_k, num_folds))

    # `split_idx`: a list of arrays, each containing the validation indices for 1 fold
    rand_idx = rnd_state.choice(n_tot, size=n_tot, replace=False)
    
    split_idx = np.array_split(rand_idx, num_folds)

    for fold_idx in range(num_folds):
        # Set the indices in boolean mask for all validation samples to `True`
        val_mask = np.zeros(n_tot, dtype=bool)
        #print(split_idx[fold_idx])
        val_mask[split_idx[fold_idx]] = True
    
        # Split training set in training part and validation part
        # Hint: you can use boolean mask as index vector to split Xtr and Ytr
        x_train = Xtr[~val_mask]
        y_train = Ytr[~val_mask]
        x_val = Xtr[val_mask]
        y_val = Ytr[val_mask] 
        
        for k_idx, current_k in enumerate(k_list):
            # Compute the training error of the kNN classifier for the given value of k
            Ypre_tr =  kNNClassify(x_train,y_train,current_k,x_train)
            current_tr_err = calcError(Ypre_tr,y_train)
            tr_errors[k_idx, fold_idx] = current_tr_err
            # Compute the validation error of the kNN classifier for the given value of k
            Ypre_val =  kNNClassify(x_train,y_train,current_k,x_val)
            current_val_err = calcError(Ypre_val,y_val)
            val_errors[k_idx, fold_idx] = current_val_err


    # Calculate error statistics along the repetitions:
    # 1) mean training error, training error standard deviation
    tr_err_mean = np.mean(tr_errors,axis=1)  
    #print("tr_err_mean:" ,tr_err_mean) 
    tr_err_std = np.std(tr_errors,axis=1)
    # 2) mean validation error, validation error standard deviation
    val_err_mean = np.mean(val_errors,axis=1)
    val_err_std = np.std(val_errors,axis=1)
    # 3) best k (k which minimize mean validation error) and index of best k in k_list
    best_k = k_list[np.argmin(val_err_mean)]
    best_k_idx = np.argmin(val_err_mean)
    
    return best_k, best_k_idx, tr_err_mean, tr_err_std, val_err_mean, val_err_std

# %%
# Perform the same analysis of Assignment 5 using K-Fold CV
# INSERT YOUR CODE HERE
# Use dataset 4 for this task.
num_folds=5

Xtr, Ytr, Xte, Yte = load_dataset(training_set_path, test_set_path)
#1. Choose a list of values of k based list of suggested ( in this example of dataset 4 range (1...19) )
k_list_4 = range(1,19)

best_k, best_k_idx, tr_err_mean, tr_err_std, val_err_mean, val_err_std = KFoldCVkNN(Xtr,Ytr,num_folds,k_list_4)


print(f"The best k chosen with the training-set is: {best_k}\n")

# 4. Evaluate the model with the best k on the test set now
Ypre_best_k =  kNNClassify(Xtr,Ytr,best_k,Xte)
te_err = calcError(Ypre_best_k,Yte)
#Then the estimate for the test error is the mean of the error of the K different models.
#te_err = np.mean(tr_err_mean)
    
print(f"The test error with the best k ({best_k}) is: {te_err*100:.2f}%")
# Out:
# The best k chosen with the training-set is: 11
#
# The test error with the best k (11) is: 7.50%

# %% [markdown]
# Does the best k (and the test error) change w.r.t. assignment 5?
#
# - Yes , they change compared to assignment 5 , because who minimize the mean validation error using the K-Fold ( ex k=15 and error = 7 % )

# %% [markdown]
# --------------------------------------------------------

# %% [markdown]
# ## Assignment 7: Cross validation and Noise in k-NN
#
# In this final task we consider the effect of noise on the best k (chosen with k-fold CV).
#
# We will use dataset 3 which has high noise (20%), and dataset 4 which has low noise (5%).
#
# You will have to do the following:
#  1. Use k-fold CV to find the best k for datasets 3 and 4.
#  2. Compare the obtained values of k, with the actual best k on the test error of the two datasets. This should be a sanity check: if the errors on k-fold CV and on the test set are very different, something may be wrong with your code.
#  3. Comment on how noise affects the best k: does a more noisy dataset need a higher or a lower k, and why? It may be useful to plot the separating function (using the `separatingFkNN` function) of k-NN with the best k for the two datasets.

# %%
num_folds = 5
k_list = list(range(1, 32))

# %% [markdown]
# **Dataset 3 (high noise)**

# %%
# Load dataset 3 (high noise)
Xtr, Ytr, Xte, Yte = load_dataset(
    "./Material/Classification/Training3.dat", "./Material/Classification/Test3.dat")

# %%
#TODO: Find the best k on the test set of dataset 3
best_k, best_k_idx, tr_err_mean, tr_err_std, val_err_mean, val_err_std = KFoldCVkNN(Xte,Yte,num_folds,k_list)

print(f"The best k chosen with the training-set is: {best_k}\n")
# Out:
# The best k chosen with the training-set is: 19

# %%
#TODO: Compute the test error
# Evaluate the model with the best k on the test set
Ypre_best_k =  kNNClassify(Xtr,Ytr,best_k,Xte)
te_err = calcError(Ypre_best_k,Yte)
    
print(f"The test error with the best k ({best_k}) is: {te_err*100:.2f}%")
# Out:
# The test error with the best k (19) is: 22.50%

# %%
#TODO: Plot separatingFkNN on the TRAINING SET
separatingFkNN(Xtr,Ytr,best_k,Xtr)

# %% [markdown]
# **Dataset 4 (low noise)**

# %%
# Load dataset 4 (low noise)
k_list = list(range(1, 19))
Xtr, Ytr, Xte, Yte = load_dataset(
    "./Material/Classification/Training4.dat", "./Material/Classification/Test4.dat")

# %%
#TODO: Find the best k on the test set of dataset 4
best_k, best_k_idx, tr_err_mean, tr_err_std, val_err_mean, val_err_std = KFoldCVkNN(Xte,Yte,num_folds,k_list)

print(f"The best k chosen with the training-set is: {best_k}\n")
# Out:
# The best k chosen with the training-set is: 5

# %%
#TODO: Compute the test error
Ypre_best_k =  kNNClassify(Xtr,Ytr,best_k,Xte)
te_err = calcError(Ypre_best_k,Yte)
    
print(f"The test error with the best k ({best_k}) is: {te_err*100:.2f}%")
# Out:
# The test error with the best k (5) is: 6.50%

# %%
#TODO: Plot separatingFkNN on the TRAINING SET
separatingFkNN(Xtr,Ytr,best_k,Xtr)

# %% [markdown]
# How does noise affect the best k?
#
# #### Observations:...
#
# - Evaluating the TEST SET on best k in a HIGH NOSE DATASET the error (compared with the one without noise)  percentage increase ( ex . from 7% to 21 % in Dataset 3)
# - While evaluating the TEST SET on best k in a LOW NOSE DATASET the error (compared with the one without noise)  percentage reaming stable ( ex . from 7% to 10.50 % in Dataset 4)
